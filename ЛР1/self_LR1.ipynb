# %% [markdown]
# ### 1. Импортируйте библиотеки для работы с данными

# %%
#импортируйте numpy и pandas
import pandas as pd
import numpy as np

# %% [markdown]
# ###  2. Загрузите данные в рабочее пространство

# %%
car_sales = pd.read_csv('/Users/timofey/Бауманка/2024 осень/DS/ЛР1/Car_sales.csv', sep=',')

# %%
car_sales
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %% [markdown]
# ### 3. Выведите названия столбцов

# %%
for idx, column in enumerate(car_sales.columns, 1):
    print(f'{idx:2}. {column}')
# Out:
#  1. Manufacturer
#  2. Model
#  3. Sales_in_thousands
#  4. __year_resale_value
#  5. Vehicle_type
#  6. Price_in_thousands
#  7. Engine_size
#  8. Horsepower
#  9. Wheelbase
# 10. Width
# 11. Length
# 12. Curb_weight
# 13. Fuel_capacity
# 14. Fuel_efficiency
# 15. Latest_Launch
# 16. Power_perf_factor

# %% [markdown]
# ###  4. Выведите информацию о размере данных

# %%
car_sales.shape
# Out:
# (157, 16)

# %%
print(f'Кол-во строк: {car_sales.shape[0]}\nКол-во столбцов: {car_sales.shape[1]}')
# Out:
# Кол-во строк: 157
# Кол-во столбцов: 16

# %% [markdown]
# ###  5. Выведите первые 20 строк

# %%
car_sales.head(20)
# Out:
#    Manufacturer        Model  Sales_in_thousands  __year_resale_value  \
# 0         Acura      Integra              16.919               16.360
# 1         Acura           TL              39.384               19.875
# 2         Acura           CL              14.114               18.225
# 3         Acura           RL               8.588               29.725
# 4          Audi           A4              20.397               22.255
# 5          Audi           A6              18.780               23.555
# 6          Audi           A8               1.380               39.000
# 7           BMW         323i              19.747                  NaN
# 8           BMW         328i               9.231               28.675
# 9           BMW         528i              17.527               36.125
# 10        Buick      Century              91.561               12.475
# 11        Buick        Regal              39.350               13.740
# ...

# %% [markdown]
# ###  6. Найдите уникальные значения столбцов Manufacturer, Model, Vehicle_type

# %%
car_sales['Manufacturer'].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'Honda', 'Hyundai', 'Infiniti',
#        'Jaguar', 'Jeep', 'Lexus', 'Lincoln', 'Mitsubishi', 'Mercury',
#        'Mercedes-B', 'Nissan', 'Oldsmobile', 'Plymouth', 'Pontiac',
#        'Porsche', 'Saab', 'Saturn', 'Subaru', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
car_sales['Model'].unique()
# Out:
# array(['Integra', 'TL', 'CL', 'RL', 'A4', 'A6', 'A8', '323i', '328i',
#        '528i', 'Century', 'Regal', 'Park Avenue', 'LeSabre', 'DeVille',
#        'Seville', 'Eldorado', 'Catera', 'Escalade', 'Cavalier', 'Malibu',
#        'Lumina', 'Monte Carlo', 'Camaro', 'Corvette', 'Prizm', 'Metro',
#        'Impala', 'Sebring Coupe', 'Sebring Conv.', 'Concorde', 'Cirrus',
#        'LHS', 'Town & Country', '300M', 'Neon', 'Avenger', 'Stratus',
#        'Intrepid', 'Viper', 'Ram Pickup', 'Ram Wagon', 'Ram Van',
#        'Dakota', 'Durango', 'Caravan', 'Escort', 'Mustang', 'Contour',
#        'Taurus', 'Focus', 'Crown Victoria', 'Explorer', 'Windstar',
#        'Expedition', 'Ranger', 'F-Series', 'Civic', 'Accord', 'CR-V',
#        'Passport', 'Odyssey', 'Accent', 'Elantra', 'Sonata', 'I30',
#        'S-Type', 'Wrangler', 'Cherokee', 'Grand Cherokee', 'ES300',
#        'GS300', 'GS400', 'LS400', 'LX470', 'RX300', 'Continental',
# ...

# %%
car_sales['Vehicle_type'].unique()
# Out:
# array(['Passenger', 'Car'], dtype=object)

# %% [markdown]
# ### 7. Найдите число уникальных значений столбцов Manufacturer, Model, Vehicle_type

# %%
car_sales['Manufacturer'].nunique()
# Out:
# 30

# %%
car_sales['Model'].nunique()
# Out:
# 156

# %%
car_sales['Vehicle_type'].nunique()
# Out:
# 2

# %% [markdown]
# ###  8. Выведите датафрейм при Horsepower > 160

# %%
car_sales[car_sales['Horsepower'] > 160]
# Out:
#     Manufacturer         Model  Sales_in_thousands  __year_resale_value  \
# 1          Acura            TL              39.384               19.875
# 2          Acura            CL              14.114               18.225
# 3          Acura            RL               8.588               29.725
# 5           Audi            A6              18.780               23.555
# 6           Audi            A8               1.380               39.000
# ..           ...           ...                 ...                  ...
# 144       Toyota  Land Cruiser               9.835               34.080
# 153        Volvo           S70              15.245                  NaN
# 154        Volvo           V70              17.531                  NaN
# 155        Volvo           C70               3.493                  NaN
# 156        Volvo           S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %% [markdown]
# ###  9. Выполните срез фрейма из предыдущего задания для столбцов Manufacturer, Model, Vehicle_type, Horsepower

# %%
car_sales[car_sales['Horsepower'] > 160].loc[:, ['Manufacturer', 'Model', 'Vehicle_type', 'Horsepower']]
# Out:
#     Manufacturer         Model Vehicle_type  Horsepower
# 1          Acura            TL    Passenger       225.0
# 2          Acura            CL    Passenger       225.0
# 3          Acura            RL    Passenger       210.0
# 5           Audi            A6    Passenger       200.0
# 6           Audi            A8    Passenger       310.0
# ..           ...           ...          ...         ...
# 144       Toyota  Land Cruiser          Car       230.0
# 153        Volvo           S70    Passenger       168.0
# 154        Volvo           V70    Passenger       168.0
# 155        Volvo           C70    Passenger       236.0
# 156        Volvo           S80    Passenger       201.0
#
# [102 rows x 4 columns]
